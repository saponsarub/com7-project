# %%
import os
import sys

import pyodbc
import pandas as pd


server = os.environ.get("MIS_SERVER", "192.168.43.250,18963")
username = os.environ.get("MIS_USER","sapon.s")
password = os.environ.get("MIS_PWD","")

if not username or not password:
    sys.exit('ต้องตั้ง credential ก่อน:  $env:MIS_USER="..."; $env:MIS_PWD="..."')

conn = pyodbc.connect(
    f"DRIVER={{ODBC Driver 18 for SQL Server}};"
    f"SERVER={server};"
  # f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password};"
    "TrustServerCertificate=yes;"
)

print("Connected!")
query = """
SELECT ItemId, ItemName, CategoryName, SubCategoryName, [Model/Series], Brand
FROM   rpt.dim_item_itec;
"""

df = pd.read_sql(query, conn)
print(df)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[3], line 15
#      11
#      12 if not username or not password:
#      13     sys.exit('ต้องตั้ง credential ก่อน:  $env:MIS_USER="..."; $env:MIS_PWD="..."')
#      14
# ---> 15 conn = pyodbc.connect(
#      16     f"DRIVER={{ODBC Driver 18 for SQL Server}};"
#      17     f"SERVER={server};"
#      18   # f"DATABASE={database};"
#
# InterfaceError: ('28000', "[28000] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Login failed for user 'sapon.s'. (18456) (SQLDriverConnect); [28000] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Login failed for user 'sapon.s'. (18456)")
